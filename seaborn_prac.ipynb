# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./lab/tips.csv')
# sns.set_style('whitegrid')

# %%
sns.relplot(x='time', y='tip', data=data, kind='line')

# %%
sns.catplot(x='day', y='total_bill', data=data, palette='rainbow')
# Out:
# C:\Users\alokk\AppData\Local\Temp\ipykernel_23692\802846436.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x='day', y='total_bill', data=data, palette='rainbow')

# %%
sns.catplot(x='day', y='total_bill', data=data, palette='rainbow', kind='violin')

# %%
sns.catplot(x='day', y='total_bill', data=data, palette='rainbow', kind='box')

# %%
sns.catplot(x='day', y='total_bill', data=data, palette='rainbow', kind='boxen')

# %%
from scipy import stats
c = np.random.normal(loc=5, size=100, scale=2)
sns.distplot(c)
# Out:
# C:\Users\alokk\AppData\Local\Temp\ipykernel_23692\2512196505.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c)
# <Axes: ylabel='Density'>

# %%
sns.set(style='darkgrid')
a = sns.load_dataset('./lab/tips')
b = sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.lineplot(data = data, x = 'total_bill', y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x = 'day', y = 'total_bill', data = data, hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data, x='day',kind='count')

# %%
sns.histplot(data['total_bill'], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.pairplot(data, hue='smoker')

# %%
sns.relplot(data, x='total_bill', y='tip', hue='size', palette='ch:r=-.5, l=.75')

# %%
sns.relplot(data, x = 'total_bill', y = 'tip', size='size', sizes=(15, 200), palette='ch:r=-.5, l=.75')
# Out:
# C:\Users\alokk\AppData\Local\Temp\ipykernel_23692\1942892447.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(data, x = 'total_bill', y = 'tip', size='size', sizes=(15, 200), palette='ch:r=-.5, l=.75')

# %%
sns.relplot(data, x='total_bill', y = 'day', kind='line', hue='smoker')

# %%
sns.relplot(
    data,
    x='total_bill',
    y='tip',
    hue='smoker',
    col='time'
)

# %%
sns.distplot(data['total_bill'], kde=True, bins=10, color='red')
# Out:
# C:\Users\alokk\AppData\Local\Temp\ipykernel_23692\3098318323.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['total_bill'], kde=True, bins=10, color='red')
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data, x = 'total_bill', y = 'tip')

# %%
sns.displot(data, x = 'total_bill', y = 'tip', kind='kde', hue='smoker')

# %%
sns.jointplot(
    data,
    x = 'total_bill',
    y = 'tip',
    kind='kde',
    hue='smoker'
)

# %%
sns.catplot(data, x = 'day', y = 'total_bill', jitter=False)

# %%
sns.catplot(data, x = 'day', y = 'total_bill', kind='swarm')

# %%
sns.catplot(data, x = 'day', y = 'total_bill', kind='swarm', hue='sex')

# %%
sns.catplot(data, x = 'day', y = 'total_bill', kind='box')

# %%
sns.catplot(data, x = 'day', y = 'total_bill', hue='smoker', kind='box')

# %%
data['weekend'] = data['day'].isin(['Sat','Sun'])
sns.catplot(data, x = 'day', y = 'total_bill', hue='weekend', kind='box')

# %%
sns.catplot(data, x = 'day', y = 'total_bill', hue='sex', kind='violin', split=True)

# %%
g = sns.catplot(data, x = 'day', y='total_bill', kind='violin', inner=None)
sns.swarmplot(data, x = 'day', y='total_bill', color='k', size=3, ax=g.ax)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
